# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/mushroom.csv")

# %%
df
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1995         863    sunken       scaly     brown     yes     foul
# 1996        1160    sunken       scaly    purple     yes    musty
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
# 1999        1073    convex       scaly    yellow     yes  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  stalk_height  cap_diameter
# count  2000.000000   2000.000000   2000.000000
# mean    624.974000      8.449118     12.314345
# std     375.091938      3.697217      7.048845
# min       0.000000      2.000000      1.000000
# 25%     290.000000      5.291009      5.723521
# 50%     607.000000      8.318596     12.124902
# 75%     957.250000     11.781272     18.698605
# max    1279.000000     15.095066     25.000054

# %%
sns.pairplot(df) #just by looking at the graph we assume that there are only 2 classes

# %%
df['population'].value_counts() # there are actually 3 classes. 2 classes might be overlapping
# Out:
# population
# abundant     360
# clustered    340
# several      335
# solitary     332
# numerous     323
# scattered    310
# Name: count, dtype: int64

# %%
sns.pairplot(df,hue = 'population') # now we can see 3 classes
# in 2D subspace they are overlapped. In 3D subspace it will not overlap.
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
# 3         282      bell       scaly      pink     yes  fishy         notched
# 4         820      flat      smooth    yellow     yes  musty            free
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
# 3        close     broad     orange  ...    partial     yellow         two
# 4      crowded    narrow     orange  ...  universal      white        none
#
# ...

# %%
df.shape
# Out:
# (2000, 26)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df.iloc[:,-1] = le.fit_transform(df.iloc[:,-1])

# %%
df['population'].value_counts()
# Out:
# population
# abundant     360
# clustered    340
# several      335
# solitary     332
# numerous     323
# scattered    310
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
# 3         282      bell       scaly      pink     yes  fishy         notched
# 4         820      flat      smooth    yellow     yes  musty            free
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
# 3        close     broad     orange  ...    partial     yellow         two
# 4      crowded    narrow     orange  ...  universal      white        none
#
# ...

# %%
from sklearn.svm import SVC

# %%
svc = SVC() # use default values because data is in good format

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,25:27]
y = df['population']

# %%
y
# Out:
# 0       clustered
# 1        numerous
# 2        abundant
# 3       clustered
# 4       clustered
#           ...
# 1995     abundant
# 1996     numerous
# 1997     abundant
# 1998     solitary
# 1999     numerous
# Name: population, Length: 2000, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
y_train
# Out:
# 1045     numerous
# 937      solitary
# 1658      several
# 529       several
# 895     clustered
#           ...
# 835       several
# 1216    scattered
# 1653      several
# 559     clustered
# 684      abundant
# Name: population, Length: 1500, dtype: object

# %%
y_train = le.fit_transform(y_train)

# %%
y_train
# Out:
# array([2, 5, 4, ..., 4, 1, 0])

# %%
df['population'].unique()
# Out:
# array(['clustered', 'numerous', 'abundant', 'scattered', 'several',
#        'solitary'], dtype=object)

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
ypred = svc.predict(x_test)

# %%
ypred
# Out:
# array([4, 0, 1, 5, 4, 0, 5, 4, 0, 5, 1, 0, 0, 4, 5, 0, 5, 5, 1, 5, 5, 0,
#        1, 0, 0, 5, 0, 1, 5, 0, 5, 5, 1, 5, 1, 0, 0, 4, 0, 0, 0, 1, 0, 5,
#        5, 5, 5, 5, 1, 0, 0, 1, 5, 5, 0, 0, 0, 0, 5, 5, 1, 4, 0, 5, 5, 1,
#        0, 5, 5, 5, 5, 5, 5, 5, 0, 0, 0, 0, 4, 5, 5, 5, 0, 5, 4, 5, 1, 1,
#        1, 1, 1, 0, 5, 0, 1, 1, 1, 1, 5, 1, 0, 0, 5, 5, 1, 5, 1, 5, 1, 1,
#        0, 5, 1, 0, 4, 5, 0, 1, 0, 5, 0, 1, 5, 0, 4, 5, 0, 1, 0, 5, 0, 5,
#        0, 5, 0, 4, 0, 1, 1, 1, 0, 0, 0, 0, 5, 5, 5, 0, 1, 0, 4, 0, 1, 0,
#        5, 5, 5, 0, 5, 1, 0, 5, 5, 0, 1, 5, 4, 1, 0, 0, 5, 1, 0, 5, 1, 5,
#        1, 5, 0, 1, 5, 5, 0, 0, 1, 5, 4, 0, 5, 1, 1, 5, 4, 4, 1, 0, 5, 1,
#        5, 0, 5, 0, 1, 1, 5, 5, 1, 5, 5, 0, 5, 1, 1, 1, 0, 5, 5, 5, 0, 1,
#        5, 0, 5, 1, 0, 0, 5, 1, 4, 5, 5, 5, 4, 5, 0, 5, 1, 5, 5, 1, 1, 5,
#        1, 0, 1, 0, 5, 5, 1, 5, 5, 4, 5, 5, 0, 0, 4, 5, 5, 5, 1, 5, 5, 4,
#        0, 0, 5, 1, 5, 1, 5, 0, 1, 1, 5, 1, 0, 0, 5, 0, 0, 1, 0, 0, 0, 5,
# ...

# %%
y_test = le.fit_transform(y_test)

# %%
print(svc.score(x_train,y_train),svc.score(x_test,y_test))
# Out:
# 0.22133333333333333 0.188

# %% [markdown]
# #Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'C' : [0.1,0.001,1,2,3,4,5],
    'kernel' : ['linear','poly','rbf'],
    'gamma' : [0.1,0.001,1,2,5]
}# C, kernel and gamma values: https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
print('Training Accuracy',svc.score(x_train,y_train))
print('Testing Accuracy',svc.score(x_test,y_test))

# %%
svc = SVC(C=0.1,gamma=0.1,kernel='poly')

# %%
svc.fit(x_train,y_train)
ypred = svc.predict(x_test)

# %%
print('Training Accuracy',svc.score(x_train,y_train))
print('Testing Accuracy',svc.score(x_test,y_test))
